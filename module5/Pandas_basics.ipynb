# %% [markdown]
# # Introduction to Pandas for Data Analysis
#
# **Welcome to the Pandas Basics Tutorial!**
#
# This notebook is designed to teach you the fundamentals of Pandas, Python's most powerful library for data manipulation and analysis. Whether you're working with economic data, financial records, or research datasets, Pandas provides the essential tools you need.
#
# ## What You'll Learn
#
# Throughout this tutorial, you will:
#
# 1. **Master Pandas Data Structures** - Understand Series and DataFrames, the building blocks of data analysis
# 2. **Access and Slice Data** - Learn multiple ways to retrieve specific data using indexing operators, `.loc`, and `.iloc`
# 3. **Combine Datasets** - Merge and concatenate datasets like a pro using `.concat()` and `.merge()`
# 4. **Work with Real Data** - Practice with football club statistics and European soccer match data
#
# ## Learning Approach
#
# Each section contains:
# - **Clear explanations** of concepts
# - **Hands-on tasks** with specific instructions
# - **Empty code cells** where you'll write your solutions
# - **Progressive difficulty** - concepts build on each other
#
# ## Getting Started
#
# Write and execute each code cell in order from top to bottom. Don't skip ahead - later tasks depend on variables created in earlier ones!
#
# Let's begin your journey into data analysis with Pandas! 🐼

# %% [markdown]
# ---
#
# ---
#
#
# # Section 1. Getting to know Pandas' Data Structures
# ---
#
# ---

# %% [markdown]
# ### **Task 1**. import the pandas library, use "pd" as the alias

# %%
# %pip install pandas
import pandas as pd
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1.1. Understanding Series Objects
#
# A Pandas Series is a one-dimensional labeled array. Think of it as a single column of data in a spreadsheet or a database table. Each element in a Series has an associated label, called its index. If you don't provide an index, Pandas will automatically create a default integer index starting from 0.
#
# You can create a Series from various Python data structures like lists, arrays, or dictionaries.

# %% [markdown]
# ### **Task 2.** Create a Pandas series
# - Series name is "ranking",
# - There are five values in this series: [4, 8, 30, 2, 6]

# %%
ranking = pd.Series([4, 8, 30, 2, 6])

# %% [markdown]
# ### **Task 3**. check the *values* in the series "*ranking*"

# %%
ranking.values
# Out:
# array([ 4,  8, 30,  2,  6])

# %% [markdown]
# ### **Task 4**. Check the *index* in the series "**ranking**"

# %%
ranking.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# ### **Task 5.** use the `type()` method to check what is the data type of the *values*

# %%
type(ranking.values)
# Out:
# numpy.ndarray

# %% [markdown]
# ### **Task 6.** Create another pandas series object, do the following:
# - Name the series as **club_ranking**
# - the *values* are [4, 8, 30, 2, 6],
# - the *index* for each value: ['RMD', 'MNC', 'JUV', 'PSG', 'LIV']

# %%
club_ranking = pd.Series(
    data=[4, 8, 30, 2, 6],
    index=['RMD', 'MNC', 'JUV', 'PSG', 'LIV']
)

# %% [markdown]
# ### **Task 7**. Create a Pandas series from a python dictionary
# - name the series as **club_fans_count**
# - create a python dictionary, the *key-value pairs* are 'RMD':436.7, 'MNC':153.5
# - convert this python dictionary to a Pandas Series

# %%
fans_data = {'RMD': 436.7, 'MNC': 153.5}
club_fans_count = pd.Series(fans_data)

# %% [markdown]
# ### **Task 8**. call the `.keys()` method in the **club_fans_count**, what's the return?

# %%
club_fans_count.keys()
# Out:
# Index(['RMD', 'MNC'], dtype='object')

# %% [markdown]
# ### **Task 9**. Find out if the index "LIV" in the Series '**club_fans_count**'

# %%
'LIV' in club_fans_count.index
# Out:
# False

# %% [markdown]
# ## 1.2. Understanding DataFrame Objects
#
# A Pandas DataFrame is a two-dimensional labeled data structure with columns of potentially different types. You can think of it as a spreadsheet or a SQL table. It is the most commonly used Pandas object and is ideal for representing real-world data.
#
# DataFrames can be created from various sources, including dictionaries of Series, lists of dictionaries, NumPy arrays, and other DataFrames.

# %% [markdown]
# ### **Task 10**. Create a DataFrame by doing:
# * Create a Dictionary with the following key:value pairs:
#   * "ranking": club_ranking
#   * "fans_count": club_fans_count
# * Convert the dictionary to a dataframe, name it as **club_data**

# %%
data = {
    "ranking": club_ranking,
    "fans_count": club_fans_count
}
club_data = pd.DataFrame(data)

# %% [markdown]
# ### **Task 11**. check some attribute of the dataframe **club_data**
# * access the *index* attribute
# * access the *shape* attribute
# * access the *axes* attribute

# %%
print(club_data.index)
print(club_data.shape)
print(club_data.axes)
# Out:
# Index(['JUV', 'LIV', 'MNC', 'PSG', 'RMD'], dtype='object')
# (5, 2)
# [Index(['JUV', 'LIV', 'MNC', 'PSG', 'RMD'], dtype='object'), Index(['ranking', 'fans_count'], dtype='object')]

# %% [markdown]
# ### **Task 12**. Call the `keys()` method of **club_data**, see what the return is

# %%
club_data.keys()
# Out:
# Index(['ranking', 'fans_count'], dtype='object')

# %% [markdown]
# ### **Task 13**. check if "LIV" is in the **index/column** of the **club_data** df

# %%
print('LIV' in club_data.index)
print('LIV' in club_data.columns)
# Out:
# True
# False

# %% [markdown]
# ### **Task 14**. check if "ranking" is in the **index/column** of the club_data df

# %%
print('ranking' in club_data.index)
print('ranking' in club_data.columns)
# Out:
# False
# True

# %% [markdown]
# ---
#
# ---
#
#
# # Section 2. Accessing Series Elements
# ---
#
# ---

# %% [markdown]
# ## 2.1. Using the Indexing Operator
#
# The indexing operator `[]` is a fundamental way to access elements in both Pandas Series and DataFrames.
#
# For **Series**, you can use `[]` with:
# - A single label (index value) to get a single element.
# - A list of labels to get multiple elements.
# - A slice of labels to get a range of elements.
# - A boolean array to filter elements.
#
# For **DataFrames**, you can use `[]` with:
# - A single column name (as a string) to select a Series (a single column).
# - A list of column names to select a DataFrame (multiple columns).
# - A boolean array to filter rows.

# %% [markdown]
# ### **Task 15**. Use positional index to get all elements except the first one in the df **club_ranking**

# %% [markdown]
# ### **Task 16**. Use label index to get all elements after MNC in the Series **club_ranking**

# %% [markdown]
# ## 2.2. Caveat with indexing operator '[]'
#
# While `[]` is versatile, it's important to understand its behavior, especially when using integer-based indexing, as it can sometimes behave differently depending on the index of the Series or DataFrame. We'll explore this nuance later.

# %% [markdown]
# ### **Task 17**. Generate a Pandas Series with the following values and index
# - Series name is "**colors**"
# - value: ["red", "purple", "blue", "green", "yellow"]
# - index: [1, 2, 3, 5, 8]

# %% [markdown]
# ### **Task 18**. Compare a few operations:
# - What will `colors[1]` returns?
# - what will `colors[0]` returns?
# - Are they the same as what you expected?

# %% [markdown]
# ## 2.3. Using `.loc` and `.iloc`
#
# To avoid confusion and ensure explicit indexing, Pandas provides two attribute accessors:
#
# *   `.loc`: This is primarily used for **label-based indexing**. You use the actual labels (index names or column names) to select data.
# *   `.iloc`: This is primarily used for **integer position-based indexing**. You use the numerical position of the rows and columns (starting from 0) to select data.
#
# These accessors make your code more readable and predictable, especially when dealing with Series or DataFrames that have non-standard integer indexes.

# %% [markdown]
# ### **Task 19**. use `.iloc` to get the second and third elements in the Series **colors**

# %% [markdown]
# ###**Task 20.** use `.iloc` to get the last element in the series **colors** (try pass a negative positional index and see what it returns)

# %% [markdown]
# ---
#
# ---
#
#
# # Section 3. Accessing DataFrame Elements
# ---
#
# ---

# %% [markdown]
# ## 3.1. Using the index operator

# %% [markdown]
# ### **Task 21**. use index operator `[]` to get the information of the column "ranking" from the dataframe **club_data**

# %% [markdown]
# ### **Task 22**. try use the dot syntax to get the information on 'ranking' in the dataframe **club_data**

# %% [markdown]
# ## 3.2. Using .loc and .iloc

# %% [markdown]
# ### **Task 23**. use `.loc` to get information for the club **"LIV"**.
#
# ---

# %% [markdown]
# ### **Task 24.** use `.loc` to get information from the club **"MNC"** to **"LIV"**

# %% [markdown]
# ### **Task 25**. use `.iloc` to get the information from the second column in the df **club_data**

# %% [markdown]
# ###**Task 26**. use `.loc` to get **'ranking'** information for clubs from **RMD** to **JUV**

# %% [markdown]
# ---
#
# ---
#
#
# # Section 4. Combining Datasets
# ---
#
# ---

# %% [markdown]
# In many data analysis tasks, you'll need to combine information from multiple sources. Pandas provides powerful tools to merge and concatenate DataFrames and Series.
#
# The two most common methods for combining datasets are:
#
# *   `.concat()`: Primarily used for stacking DataFrames or Series either vertically (adding rows) or horizontally (adding columns).
# *   `.merge()`: Primarily used for combining DataFrames based on common columns or index values, similar to SQL joins.
#
# We will explore these methods in more detail in this section.

# %% [markdown]
# ## 4.1. use `.concat()` to join datasets

# %% [markdown]
# ### **Task 27**. Run the coding block below to get a new dataframe **more_club_data**

# %%
# generate more data for football clubs
import pandas as pd
more_club_data = pd.DataFrame(
    {"ranking": [5, 1],
     "fans_count": [360.5, 126.5]},
    index=["BAR", "BAY"]
)

# %% [markdown]
# ###**Task 28**. use `.concat()` to join club_data and more_club_data together, name the new dataframe as **all_club_data**

# %% [markdown]
# ### **Task 29**. run the code block below to get a new dataframe **countries**

# %%
# generate a new dataframe with some countries
countries = pd.DataFrame({
    "country": ["England", "Spain", "Italy", "France"]},
    index=["LIV", "BAR", "JUV", "PSG"]
)

print(countries)
# Out:
#      country
# LIV  England
# BAR    Spain
# JUV    Italy
# PSG   France

# %% [markdown]
# ### **Task 30**. use `.concat()` to join **countries** with **all_club_data**
# - the *country* shall become a new column of the joined dataframe
# - name the new dataframe as **all_clubs_with_country**

# %% [markdown]
# ## 4.2. use `.merge()` to join datasets

# %% [markdown]
# ### **Task 31**. Run the following code block to get a new dataframe **european_champions_title**

# %%
european_champions_title = pd.DataFrame({
    "full name": ["Liverpool FC", "FC Barcelona", "Real Madrid CF",
                  "Paris Saint-Germain FC", "Juventus FC"],
    "UEFA titles": [6, 5, 15, 1, 2],
    "country": ["England", "Spain", "Spain", "France", "Italy"]},
    index=["LIV", "BAR", "RMD", "PSG", "JUV"])

print(european_champions_title)
# Out:
#                   full name  UEFA titles  country
# LIV            Liverpool FC            6  England
# BAR            FC Barcelona            5    Spain
# RMD          Real Madrid CF           15    Spain
# PSG  Paris Saint-Germain FC            1   France
# JUV             Juventus FC            2    Italy

# %% [markdown]
# There are several ways that we could merge two dataset together, and the differences among them are nuanced but important
# left merge
# right merge
# inner merge
# outer merge
#
# interpretation for each of them

# %% [markdown]
# ### **Task 32**. merge **all_clubs_with_country** and **european_champions_title** together on *index*, with *left* merge, name the new df as **left_merged_df**

# %% [markdown]
# ### **Task 33**. merge **all_clubs_with_country** and **european_champions_title** together on *index*, with *right* merge,  name the new df as **right_merged_df**

# %% [markdown]
# ### **Task 34** merge **all_clubs_with_country** and **european_champions_title** together on index, with *inner* merge,  name the new df as **inner_merged_df**

# %% [markdown]
# ### **Task 35**. merge **all_clubs_with_country** and **european_champions_title** together on *index*, with *outer* merge,  name the new df as **outer_merged_df**

# %% [markdown]
# ### **Task 36**. merge **all_clubs_with_country** and **european_champions_title** together on *ranking*, with *inner* merge, name the new df as **merged_on_ranking_inner**

# %% [markdown]
# ### **Task 37**. merge **all_clubs_with_country** and **european_champions_title** together on *country*, with *inner* merge, name the new df as **merged_on_country_inner**

# %% [markdown]
# ### **Task 38**. Export the dataframe **merged_on_country_inner**, name the saved file as **merged_data.csv**
